# %% [markdown]
# # Exploratory Data Analysis & Visualization
# ## Credit Card Fraud Detection Dataset
#
# This notebook performs comprehensive exploratory data analysis on the credit card fraud dataset.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

# Set plot style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Load datasets
card_trans_df = pd.read_csv('../Datasets/card_transdata.csv')
creditcard_df = pd.read_csv('../Datasets/creditcard.csv')

print("Card Transaction Data Shape:", card_trans_df.shape)
print("Credit Card Data Shape:", creditcard_df.shape)

# %%
# Display first few rows
print("Card Transaction Data - First 5 rows:")
print(card_trans_df.head())
print("\nCredit Card Data - First 5 rows:")
print(creditcard_df.head())

# %%
# Data types and info
print("Card Transaction Data Info:")
print(card_trans_df.info())
print("\n" + "="*50 + "\n")
print("Credit Card Data Info:")
print(creditcard_df.info())

# %%
# Statistical summary
print("Card Transaction Data - Statistical Summary:")
print(card_trans_df.describe())
print("\n" + "="*50 + "\n")
print("Credit Card Data - Statistical Summary:")
print(creditcard_df.describe())

# %%
# Check for missing values
print("Card Transaction Data - Missing Values:")
print(card_trans_df.isnull().sum())
print("\n" + "="*50 + "\n")
print("Credit Card Data - Missing Values:")
print(creditcard_df.isnull().sum())

# %%
# Add your visualization code here
# Explore distributions, correlations, and patterns
